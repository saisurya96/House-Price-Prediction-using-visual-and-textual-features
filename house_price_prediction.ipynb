# %% [markdown]
# ## Testing Places365 CNN (AlexNet)

# %%
import torch
from torch.autograd import Variable as V
import torchvision.models as models
from torchvision import transforms as trn
from torch.nn import functional as F
import os
from PIL import Image
import numpy as np
import torch.nn as nn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
import pandas as pd

# %%
# PlacesCNN for scene classification
#
# by Bolei Zhou
# last modified by Bolei Zhou, Dec.27, 2017 with latest pytorch and torchvision 
# (upgrade your torchvision please if there is trn.Resize error)



# the architecture to use
arch = 'alexnet'

# load the pre-trained weights
model_file = '%s_places365.pth.tar' % arch
if not os.access(model_file, os.W_OK):
    weight_url = 'http://places2.csail.mit.edu/models_places365/' + model_file
    os.system('wget ' + weight_url)

model = models.__dict__[arch](num_classes=365)
checkpoint = torch.load(model_file, map_location=lambda storage, loc: storage)
state_dict = {str.replace(k,'module.',''): v for k,v in checkpoint['state_dict'].items()}
model.load_state_dict(state_dict)
model.eval()


# load the image transformer
centre_crop = trn.Compose([
        trn.Resize((256,256)),
        trn.CenterCrop(224),
        trn.ToTensor(),
        trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# load the class label
file_name = 'categories_places365.txt'
if not os.access(file_name, os.W_OK):
    synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
    os.system('wget ' + synset_url)
classes = list()
with open(file_name) as class_file:
    for line in class_file:
        classes.append(line.strip().split(' ')[0][3:])
classes = tuple(classes)

# load the test image
img_name = '1_in.jpg'
if not os.access(img_name, os.W_OK):
    img_url = 'http://places.csail.mit.edu/demo/' + img_name
    os.system('wget ' + img_url)

img = Image.open(img_name)
input_img = V(centre_crop(img).unsqueeze(0))

# forward pass
logit = model.forward(input_img)
h_x = F.softmax(logit, 1).data.squeeze()
probs, idx = h_x.sort(0, True)

print('{} prediction on {}'.format(arch,img_name))
# output the prediction
for i in range(0, 5):
    print('{:.3f} -> {}'.format(probs[i], classes[idx[i]]))
# Out:
# alexnet prediction on 1_in.jpg
# 0.329 -> mezzanine
# 0.191 -> living_room
# 0.158 -> entrance_hall
# 0.123 -> television_room
# 0.090 -> artists_loft

# %% [markdown]
# ## Viewing Model architecture

# %%
model
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=365, bias=True)
#   )
# )

# %% [markdown]
# ## Amending the classifier layer to include only untill fc4 layer

# %%
new_classifier = nn.Sequential(*list(model.classifier.children())[:-1])
model.classifier = new_classifier

# %% [markdown]
# ## Extracting 4096 features by passing the image through our new model
#
# Each image (5) of each house (2000), are passed through the CNN to isolate values (4096) from FC4 layer.
# These values are then stored in the form of .npy files in a separate folder for each house.

# %%
# Get the list of all files and directories
# in the root directory
path = r"C:\Users\Vaddi\CPS 595\Houses"
dir_list = os.listdir(path)

dir_list = [x.lower() for x in dir_list]

# %%
type(dir_list)
# Out:
# list

# %%
#applying natural sort on directory list
from natsort import os_sorted
dir_list = os_sorted(dir_list)

# %%
#validating list of files
dir_df = pd.DataFrame(dir_list, columns = ['file_names'])
dir_df_grp = dir_df.copy()
temp = dir_df['file_names'].str.split('_', expand = True)
dir_df_grp['sno'] = temp[0]
dir_df_grp['room_name'] = temp[1]

dir_df_grp = dir_df_grp[['sno','room_name']]

dir_df_count = dir_df_grp.groupby('sno').count()

#to check if each house has exactly 5 pictures
dir_df_count[dir_df_count['room_name'] != 5]
# Out:
# Empty DataFrame
# Columns: [room_name]
# Index: []

# %%
dir_df
# Out:
#           file_names
# 0         1_bath.jpg
# 1          1_bed.jpg
# 2           1_in.jpg
# 3          1_kit.jpg
# 4          1_out.jpg
# ...              ...
# 14995  3000_bath.jpg
# 14996   3000_bed.jpg
# 14997    3000_in.jpg
# 14998   3000_kit.jpg
# 14999   3000_out.jpg
#
# [15000 rows x 1 columns]

# %%
15000//5+1
# Out:
# 3001

# %%
#for each house
for x in range(1, (len(dir_df)//5+1), 1):
    print('at house ' + str(x))
    house_pics = dir_df[dir_df['file_names'].str.startswith(str(x)+'_')].copy()
    house_pics = house_pics.reset_index(drop=True)
    feats = []
    
    #for each house's pictures (5)
    for i in range(5):
        fname = house_pics['file_names'][i]
        img = Image.open(path+"\\"+fname)
        input_img = V(centre_crop(img).unsqueeze(0))
        feat = model.forward(input_img)
        feat = feat.tolist()[0]
        feats.extend(feat)

    path2 = 'house_feats' + '\\' + str(x)
    os.mkdir(path2)

    np.save(path2 + '\\'+ str(x), feats)
    print(str(x) + ' house done')
# Out:
# at house 1
# 1 house done
# at house 2
# 2 house done
# at house 3
# 3 house done
# at house 4
# 4 house done
# at house 5
# 5 house done
# at house 6
# 6 house done
# at house 7
# 7 house done
# at house 8
# 8 house done
# at house 9
# 9 house done
# at house 10
# 10 house done
# at house 11
# 11 house done
# at house 12
# 12 house done
# at house 13
# 13 house done
# at house 14
# 14 house done
# at house 15
# 15 house done
# at house 16
# 16 house done
# at house 17
# 17 house done
# at house 18
# 18 house done
# at house 19
# 19 house done
# at house 20
# 20 house done
# at house 21
# 21 house done
# at house 22
# 22 house done
# at house 23
# 23 house done
# at house 24
# 24 house done
# at house 25
# 25 house done
# at house 26
# 26 house done
# at house 27
# 27 house done
# at house 28
# 28 house done
# at house 29
# 29 house done
# at house 30
# 30 house done
# at house 31
# 31 house done
# at house 32
# 32 house done
# at house 33
# 33 house done
# at house 34
# 34 house done
# at house 35
# 35 house done
# at house 36
# 36 house done
# at house 37
# 37 house done
# at house 38
# 38 house done
# at house 39
# 39 house done
# at house 40
# 40 house done
# at house 41
# 41 house done
# at house 42
# 42 house done
# at house 43
# 43 house done
# at house 44
# 44 house done
# at house 45
# 45 house done
# at house 46
# 46 house done
# at house 47
# 47 house done
# at house 48
# 48 house done
# at house 49
# 49 house done
# at house 50
# 50 house done
# at house 51
# 51 house done
# at house 52
# 52 house done
# at house 53
# 53 house done
# at house 54
# 54 house done
# at house 55
# 55 house done
# at house 56
# 56 house done
# at house 57
# 57 house done
# at house 58
# 58 house done
# at house 59
# 59 house done
# at house 60
# 60 house done
# at house 61
# 61 house done
# at house 62
# 62 house done
# at house 63
# 63 house done
# at house 64
# 64 house done
# at house 65
# 65 house done
# at house 66
# 66 house done
# at house 67
# 67 house done
# at house 68
# 68 house done
# at house 69
# 69 house done
# at house 70
# 70 house done
# at house 71
# 71 house done
# at house 72
# 72 house done
# at house 73
# 73 house done
# at house 74
# 74 house done
# at house 75
# 75 house done
# at house 76
# 76 house done
# at house 77
# 77 house done
# at house 78
# 78 house done
# at house 79
# 79 house done
# at house 80
# 80 house done
# at house 81
# 81 house done
# at house 82
# 82 house done
# at house 83
# 83 house done
# at house 84
# 84 house done
# at house 85
# 85 house done
# at house 86
# 86 house done
# at house 87
# 87 house done
# at house 88
# 88 house done
# at house 89
# 89 house done
# at house 90
# 90 house done
# at house 91
# 91 house done
# at house 92
# 92 house done
# at house 93
# 93 house done
# at house 94
# 94 house done
# at house 95
# 95 house done
# at house 96
# 96 house done
# at house 97
# 97 house done
# at house 98
# 98 house done
# at house 99
# 99 house done
# at house 100
# 100 house done
# at house 101
# 101 house done
# at house 102
# 102 house done
# at house 103
# 103 house done
# at house 104
# 104 house done
# at house 105
# 105 house done
# at house 106
# 106 house done
# at house 107
# 107 house done
# at house 108
# 108 house done
# at house 109
# 109 house done
# at house 110
# 110 house done
# at house 111
# 111 house done
# at house 112
# 112 house done
# at house 113
# 113 house done
# at house 114
# 114 house done
# at house 115
# 115 house done
# at house 116
# 116 house done
# at house 117
# 117 house done
# at house 118
# 118 house done
# at house 119
# 119 house done
# at house 120
# 120 house done
# at house 121
# 121 house done
# at house 122
# 122 house done
# at house 123
# 123 house done
# at house 124
# 124 house done
# at house 125
# 125 house done
# at house 126
# 126 house done
# at house 127
# 127 house done
# at house 128
# 128 house done
# at house 129
# 129 house done
# at house 130
# 130 house done
# at house 131
# 131 house done
# at house 132
# 132 house done
# at house 133
# 133 house done
# at house 134
# 134 house done
# at house 135
# 135 house done
# at house 136
# 136 house done
# at house 137
# 137 house done
# at house 138
# 138 house done
# at house 139
# 139 house done
# at house 140
# 140 house done
# at house 141
# 141 house done
# at house 142
# 142 house done
# at house 143
# 143 house done
# at house 144
# 144 house done
# at house 145
# 145 house done
# at house 146
# 146 house done
# at house 147
# 147 house done
# at house 148
# 148 house done
# at house 149
# 149 house done
# at house 150
# 150 house done
# at house 151
# 151 house done
# at house 152
# 152 house done
# at house 153
# 153 house done
# at house 154
# 154 house done
# at house 155
# 155 house done
# at house 156
# 156 house done
# at house 157
# 157 house done
# at house 158
# 158 house done
# at house 159
# 159 house done
# at house 160
# 160 house done
# at house 161
# 161 house done
# at house 162
# 162 house done
# at house 163
# 163 house done
# at house 164
# 164 house done
# at house 165
# 165 house done
# at house 166
# 166 house done
# at house 167
# 167 house done
# at house 168
# 168 house done
# at house 169
# 169 house done
# at house 170
# 170 house done
# at house 171
# 171 house done
# at house 172
# 172 house done
# at house 173
# 173 house done
# at house 174
# 174 house done
# at house 175
# 175 house done
# at house 176
# 176 house done
# at house 177
# 177 house done
# at house 178
# 178 house done
# at house 179
# 179 house done
# at house 180
# 180 house done
# at house 181
# 181 house done
# at house 182
# 182 house done
# at house 183
# 183 house done
# at house 184
# 184 house done
# at house 185
# 185 house done
# at house 186
# 186 house done
# at house 187
# 187 house done
# at house 188
# 188 house done
# at house 189
# 189 house done
# at house 190
# 190 house done
# at house 191
# 191 house done
# at house 192
# 192 house done
# at house 193
# 193 house done
# at house 194
# 194 house done
# at house 195
# 195 house done
# at house 196
# 196 house done
# at house 197
# 197 house done
# at house 198
# 198 house done
# at house 199
# 199 house done
# at house 200
# 200 house done
# at house 201
# 201 house done
# at house 202
# 202 house done
# at house 203
# 203 house done
# at house 204
# 204 house done
# at house 205
# 205 house done
# at house 206
# 206 house done
# at house 207
# 207 house done
# at house 208
# 208 house done
# at house 209
# 209 house done
# at house 210
# 210 house done
# at house 211
# 211 house done
# at house 212
# 212 house done
# at house 213
# 213 house done
# at house 214
# 214 house done
# at house 215
# 215 house done
# at house 216
# 216 house done
# at house 217
# 217 house done
# at house 218
# 218 house done
# at house 219
# 219 house done
# at house 220
# 220 house done
# at house 221
# 221 house done
# at house 222
# 222 house done
# at house 223
# 223 house done
# at house 224
# 224 house done
# at house 225
# 225 house done
# at house 226
# 226 house done
# at house 227
# 227 house done
# at house 228
# 228 house done
# at house 229
# 229 house done
# at house 230
# 230 house done
# at house 231
# 231 house done
# at house 232
# 232 house done
# at house 233
# 233 house done
# at house 234
# 234 house done
# at house 235
# 235 house done
# at house 236
# 236 house done
# at house 237
# 237 house done
# at house 238
# 238 house done
# at house 239
# 239 house done
# at house 240
# 240 house done
# at house 241
# 241 house done
# at house 242
# 242 house done
# at house 243
# 243 house done
# at house 244
# 244 house done
# at house 245
# 245 house done
# at house 246
# 246 house done
# at house 247
# 247 house done
# at house 248
# 248 house done
# at house 249
# 249 house done
# at house 250
# 250 house done
# at house 251
# 251 house done
# at house 252
# 252 house done
# at house 253
# 253 house done
# at house 254
# 254 house done
# at house 255
# 255 house done
# at house 256
# 256 house done
# at house 257
# 257 house done
# at house 258
# 258 house done
# at house 259
# 259 house done
# at house 260
# 260 house done
# at house 261
# 261 house done
# at house 262
# 262 house done
# at house 263
# 263 house done
# at house 264
# 264 house done
# at house 265
# 265 house done
# at house 266
# 266 house done
# at house 267
# 267 house done
# at house 268
# 268 house done
# at house 269
# 269 house done
# at house 270
# 270 house done
# at house 271
# 271 house done
# at house 272
# 272 house done
# at house 273
# 273 house done
# at house 274
# 274 house done
# at house 275
# 275 house done
# at house 276
# 276 house done
# at house 277
# 277 house done
# at house 278
# 278 house done
# at house 279
# 279 house done
# at house 280
# 280 house done
# at house 281
# 281 house done
# at house 282
# 282 house done
# at house 283
# 283 house done
# at house 284
# 284 house done
# at house 285
# 285 house done
# at house 286
# 286 house done
# at house 287
# 287 house done
# at house 288
# 288 house done
# at house 289
# 289 house done
# at house 290
# 290 house done
# at house 291
# 291 house done
# at house 292
# 292 house done
# at house 293
# 293 house done
# at house 294
# 294 house done
# at house 295
# 295 house done
# at house 296
# 296 house done
# at house 297
# 297 house done
# at house 298
# 298 house done
# at house 299
# 299 house done
# at house 300
# 300 house done
# at house 301
# 301 house done
# at house 302
# 302 house done
# at house 303
# 303 house done
# at house 304
# 304 house done
# at house 305
# 305 house done
# at house 306
# 306 house done
# at house 307
# 307 house done
# at house 308
# 308 house done
# at house 309
# 309 house done
# at house 310
# 310 house done
# at house 311
# 311 house done
# at house 312
# 312 house done
# at house 313
# 313 house done
# at house 314
# 314 house done
# at house 315
# 315 house done
# at house 316
# 316 house done
# at house 317
# 317 house done
# at house 318
# 318 house done
# at house 319
# 319 house done
# at house 320
# 320 house done
# at house 321
# 321 house done
# at house 322
# 322 house done
# at house 323
# 323 house done
# at house 324
# 324 house done
# at house 325
# 325 house done
# at house 326
# 326 house done
# at house 327
# 327 house done
# at house 328
# 328 house done
# at house 329
# 329 house done
# at house 330
# 330 house done
# at house 331
# 331 house done
# at house 332
# 332 house done
# at house 333
# 333 house done
# at house 334
# 334 house done
# at house 335
# 335 house done
# at house 336
# 336 house done
# at house 337
# 337 house done
# at house 338
# 338 house done
# at house 339
# 339 house done
# at house 340
# 340 house done
# at house 341
# 341 house done
# at house 342
# 342 house done
# at house 343
# 343 house done
# at house 344
# 344 house done
# at house 345
# 345 house done
# at house 346
# 346 house done
# at house 347
# 347 house done
# at house 348
# 348 house done
# at house 349
# 349 house done
# at house 350
# 350 house done
# at house 351
# 351 house done
# at house 352
# 352 house done
# at house 353
# 353 house done
# at house 354
# 354 house done
# at house 355
# 355 house done
# at house 356
# 356 house done
# at house 357
# 357 house done
# at house 358
# 358 house done
# at house 359
# 359 house done
# at house 360
# 360 house done
# at house 361
# 361 house done
# at house 362
# 362 house done
# at house 363
# 363 house done
# at house 364
# 364 house done
# at house 365
# 365 house done
# at house 366
# 366 house done
# at house 367
# 367 house done
# at house 368
# 368 house done
# at house 369
# 369 house done
# at house 370
# 370 house done
# at house 371
# 371 house done
# at house 372
# 372 house done
# at house 373
# 373 house done
# at house 374
# 374 house done
# at house 375
# 375 house done
# at house 376
# 376 house done
# at house 377
# 377 house done
# at house 378
# 378 house done
# at house 379
# 379 house done
# at house 380
# 380 house done
# at house 381
# 381 house done
# at house 382
# 382 house done
# at house 383
# 383 house done
# at house 384
# 384 house done
# at house 385
# 385 house done
# at house 386
# 386 house done
# at house 387
# 387 house done
# at house 388
# 388 house done
# at house 389
# 389 house done
# at house 390
# 390 house done
# at house 391
# 391 house done
# at house 392
# 392 house done
# at house 393
# 393 house done
# at house 394
# 394 house done
# at house 395
# 395 house done
# at house 396
# 396 house done
# at house 397
# 397 house done
# at house 398
# 398 house done
# at house 399
# 399 house done
# at house 400
# 400 house done
# at house 401
# 401 house done
# at house 402
# 402 house done
# at house 403
# 403 house done
# at house 404
# 404 house done
# at house 405
# 405 house done
# at house 406
# 406 house done
# at house 407
# 407 house done
# at house 408
# 408 house done
# at house 409
# 409 house done
# at house 410
# 410 house done
# at house 411
# 411 house done
# at house 412
# 412 house done
# at house 413
# 413 house done
# at house 414
# 414 house done
# at house 415
# 415 house done
# at house 416
# 416 house done
# at house 417
# 417 house done
# at house 418
# 418 house done
# at house 419
# 419 house done
# at house 420
# 420 house done
# at house 421
# 421 house done
# at house 422
# 422 house done
# at house 423
# 423 house done
# at house 424
# 424 house done
# at house 425
# 425 house done
# at house 426
# 426 house done
# at house 427
# 427 house done
# at house 428
# 428 house done
# at house 429
# 429 house done
# at house 430
# 430 house done
# at house 431
# 431 house done
# at house 432
# 432 house done
# at house 433
# 433 house done
# at house 434
# 434 house done
# at house 435
# 435 house done
# at house 436
# 436 house done
# at house 437
# 437 house done
# at house 438
# 438 house done
# at house 439
# 439 house done
# at house 440
# 440 house done
# at house 441
# 441 house done
# at house 442
# 442 house done
# at house 443
# 443 house done
# at house 444
# 444 house done
# at house 445
# 445 house done
# at house 446
# 446 house done
# at house 447
# 447 house done
# at house 448
# 448 house done
# at house 449
# 449 house done
# at house 450
# 450 house done
# at house 451
# 451 house done
# at house 452
# 452 house done
# at house 453
# 453 house done
# at house 454
# 454 house done
# at house 455
# 455 house done
# at house 456
# 456 house done
# at house 457
# 457 house done
# at house 458
# 458 house done
# at house 459
# 459 house done
# at house 460
# 460 house done
# at house 461
# 461 house done
# at house 462
# 462 house done
# at house 463
# 463 house done
# at house 464
# 464 house done
# at house 465
# 465 house done
# at house 466
# 466 house done
# at house 467
# 467 house done
# at house 468
# 468 house done
# at house 469
# 469 house done
# at house 470
# 470 house done
# at house 471
# 471 house done
# at house 472
# 472 house done
# at house 473
# 473 house done
# at house 474
# 474 house done
# at house 475
# 475 house done
# at house 476
# 476 house done
# at house 477
# 477 house done
# at house 478
# 478 house done
# at house 479
# 479 house done
# at house 480
# 480 house done
# at house 481
# 481 house done
# at house 482
# 482 house done
# at house 483
# 483 house done
# at house 484
# 484 house done
# at house 485
# 485 house done
# at house 486
# 486 house done
# at house 487
# 487 house done
# at house 488
# 488 house done
# at house 489
# 489 house done
# at house 490
# 490 house done
# at house 491
# 491 house done
# at house 492
# 492 house done
# at house 493
# 493 house done
# at house 494
# 494 house done
# at house 495
# 495 house done
# at house 496
# 496 house done
# at house 497
# 497 house done
# at house 498
# 498 house done
# at house 499
# 499 house done
# at house 500
# 500 house done
# at house 501
# 501 house done
# at house 502
# 502 house done
# at house 503
# 503 house done
# at house 504
# 504 house done
# at house 505
# 505 house done
# at house 506
# 506 house done
# at house 507
# 507 house done
# at house 508
# 508 house done
# at house 509
# 509 house done
# at house 510
# 510 house done
# at house 511
# 511 house done
# at house 512
# 512 house done
# at house 513
# 513 house done
# at house 514
# 514 house done
# at house 515
# 515 house done
# at house 516
# 516 house done
# at house 517
# 517 house done
# at house 518
# 518 house done
# at house 519
# 519 house done
# at house 520
# 520 house done
# at house 521
# 521 house done
# at house 522
# 522 house done
# at house 523
# 523 house done
# at house 524
# 524 house done
# at house 525
# 525 house done
# at house 526
# 526 house done
# at house 527
# 527 house done
# at house 528
# 528 house done
# at house 529
# 529 house done
# at house 530
# 530 house done
# at house 531
# 531 house done
# at house 532
# 532 house done
# at house 533
# 533 house done
# at house 534
# 534 house done
# at house 535
# 535 house done
# at house 536
# 536 house done
# at house 537
# 537 house done
# at house 538
# 538 house done
# at house 539
# 539 house done
# at house 540
# 540 house done
# at house 541
# 541 house done
# at house 542
# 542 house done
# at house 543
# 543 house done
# at house 544
# 544 house done
# at house 545
# 545 house done
# at house 546
# 546 house done
# at house 547
# 547 house done
# at house 548
# 548 house done
# at house 549
# 549 house done
# at house 550
# 550 house done
# at house 551
# 551 house done
# at house 552
# 552 house done
# at house 553
# 553 house done
# at house 554
# 554 house done
# at house 555
# 555 house done
# at house 556
# 556 house done
# at house 557
# 557 house done
# at house 558
# 558 house done
# at house 559
# 559 house done
# at house 560
# 560 house done
# at house 561
# 561 house done
# at house 562
# 562 house done
# at house 563
# 563 house done
# at house 564
# 564 house done
# at house 565
# 565 house done
# at house 566
# 566 house done
# at house 567
# 567 house done
# at house 568
# 568 house done
# at house 569
# 569 house done
# at house 570
# 570 house done
# at house 571
# 571 house done
# at house 572
# 572 house done
# at house 573
# 573 house done
# at house 574
# 574 house done
# at house 575
# 575 house done
# at house 576
# 576 house done
# at house 577
# 577 house done
# at house 578
# 578 house done
# at house 579
# 579 house done
# at house 580
# 580 house done
# at house 581
# 581 house done
# at house 582
# 582 house done
# at house 583
# 583 house done
# at house 584
# 584 house done
# at house 585
# 585 house done
# at house 586
# 586 house done
# at house 587
# 587 house done
# at house 588
# 588 house done
# at house 589
# 589 house done
# at house 590
# 590 house done
# at house 591
# 591 house done
# at house 592
# 592 house done
# at house 593
# 593 house done
# at house 594
# 594 house done
# at house 595
# 595 house done
# at house 596
# 596 house done
# at house 597
# 597 house done
# at house 598
# 598 house done
# at house 599
# 599 house done
# at house 600
# 600 house done
# at house 601
# 601 house done
# at house 602
# 602 house done
# at house 603
# 603 house done
# at house 604
# 604 house done
# at house 605
# 605 house done
# at house 606
# 606 house done
# at house 607
# 607 house done
# at house 608
# 608 house done
# at house 609
# 609 house done
# at house 610
# 610 house done
# at house 611
# 611 house done
# at house 612
# 612 house done
# at house 613
# 613 house done
# at house 614
# 614 house done
# at house 615
# 615 house done
# at house 616
# 616 house done
# at house 617
# 617 house done
# at house 618
# 618 house done
# at house 619
# 619 house done
# at house 620
# 620 house done
# at house 621
# 621 house done
# at house 622
# 622 house done
# at house 623
# 623 house done
# at house 624
# 624 house done
# at house 625
# 625 house done
# at house 626
# 626 house done
# at house 627
# 627 house done
# at house 628
# 628 house done
# at house 629
# 629 house done
# at house 630
# 630 house done
# at house 631
# 631 house done
# at house 632
# 632 house done
# at house 633
# 633 house done
# at house 634
# 634 house done
# at house 635
# 635 house done
# at house 636
# 636 house done
# at house 637
# 637 house done
# at house 638
# 638 house done
# at house 639
# 639 house done
# at house 640
# 640 house done
# at house 641
# 641 house done
# at house 642
# 642 house done
# at house 643
# 643 house done
# at house 644
# 644 house done
# at house 645
# 645 house done
# at house 646
# 646 house done
# at house 647
# 647 house done
# at house 648
# 648 house done
# at house 649
# 649 house done
# at house 650
# 650 house done
# at house 651
# 651 house done
# at house 652
# 652 house done
# at house 653
# 653 house done
# at house 654
# 654 house done
# at house 655
# 655 house done
# at house 656
# 656 house done
# at house 657
# 657 house done
# at house 658
# 658 house done
# at house 659
# 659 house done
# at house 660
# 660 house done
# at house 661
# 661 house done
# at house 662
# 662 house done
# at house 663
# 663 house done
# at house 664
# 664 house done
# at house 665
# 665 house done
# at house 666
# 666 house done
# at house 667
# 667 house done
# at house 668
# 668 house done
# at house 669
# 669 house done
# at house 670
# 670 house done
# at house 671
# 671 house done
# at house 672
# 672 house done
# at house 673
# 673 house done
# at house 674
# 674 house done
# at house 675
# 675 house done
# at house 676
# 676 house done
# at house 677
# 677 house done
# at house 678
# 678 house done
# at house 679
# 679 house done
# at house 680
# 680 house done
# at house 681
# 681 house done
# at house 682
# 682 house done
# at house 683
# 683 house done
# at house 684
# 684 house done
# at house 685
# 685 house done
# at house 686
# 686 house done
# at house 687
# 687 house done
# at house 688
# 688 house done
# at house 689
# 689 house done
# at house 690
# 690 house done
# at house 691
# 691 house done
# at house 692
# 692 house done
# at house 693
# 693 house done
# at house 694
# 694 house done
# at house 695
# 695 house done
# at house 696
# 696 house done
# at house 697
# 697 house done
# at house 698
# 698 house done
# at house 699
# 699 house done
# at house 700
# 700 house done
# at house 701
# 701 house done
# at house 702
# 702 house done
# at house 703
# 703 house done
# at house 704
# 704 house done
# at house 705
# 705 house done
# at house 706
# 706 house done
# at house 707
# 707 house done
# at house 708
# 708 house done
# at house 709
# 709 house done
# at house 710
# 710 house done
# at house 711
# 711 house done
# at house 712
# 712 house done
# at house 713
# 713 house done
# at house 714
# 714 house done
# at house 715
# 715 house done
# at house 716
# 716 house done
# at house 717
# 717 house done
# at house 718
# 718 house done
# at house 719
# 719 house done
# at house 720
# 720 house done
# at house 721
# 721 house done
# at house 722
# 722 house done
# at house 723
# 723 house done
# at house 724
# 724 house done
# at house 725
# 725 house done
# at house 726
# 726 house done
# at house 727
# 727 house done
# at house 728
# 728 house done
# at house 729
# 729 house done
# at house 730
# 730 house done
# at house 731
# 731 house done
# at house 732
# 732 house done
# at house 733
# 733 house done
# at house 734
# 734 house done
# at house 735
# 735 house done
# at house 736
# 736 house done
# at house 737
# 737 house done
# at house 738
# 738 house done
# at house 739
# 739 house done
# at house 740
# 740 house done
# at house 741
# 741 house done
# at house 742
# 742 house done
# at house 743
# 743 house done
# at house 744
# 744 house done
# at house 745
# 745 house done
# at house 746
# 746 house done
# at house 747
# 747 house done
# at house 748
# 748 house done
# at house 749
# 749 house done
# at house 750
# 750 house done
# at house 751
# 751 house done
# at house 752
# 752 house done
# at house 753
# 753 house done
# at house 754
# 754 house done
# at house 755
# 755 house done
# at house 756
# 756 house done
# at house 757
# 757 house done
# at house 758
# 758 house done
# at house 759
# 759 house done
# at house 760
# 760 house done
# at house 761
# 761 house done
# at house 762
# 762 house done
# at house 763
# 763 house done
# at house 764
# 764 house done
# at house 765
# 765 house done
# at house 766
# 766 house done
# at house 767
# 767 house done
# at house 768
# 768 house done
# at house 769
# 769 house done
# at house 770
# 770 house done
# at house 771
# 771 house done
# at house 772
# 772 house done
# at house 773
# 773 house done
# at house 774
# 774 house done
# at house 775
# 775 house done
# at house 776
# 776 house done
# at house 777
# 777 house done
# at house 778
# 778 house done
# at house 779
# 779 house done
# at house 780
# 780 house done
# at house 781
# 781 house done
# at house 782
# 782 house done
# at house 783
# 783 house done
# at house 784
# 784 house done
# at house 785
# 785 house done
# at house 786
# 786 house done
# at house 787
# 787 house done
# at house 788
# 788 house done
# at house 789
# 789 house done
# at house 790
# 790 house done
# at house 791
# 791 house done
# at house 792
# 792 house done
# at house 793
# 793 house done
# at house 794
# 794 house done
# at house 795
# 795 house done
# at house 796
# 796 house done
# at house 797
# 797 house done
# at house 798
# 798 house done
# at house 799
# 799 house done
# at house 800
# 800 house done
# at house 801
# 801 house done
# at house 802
# 802 house done
# at house 803
# 803 house done
# at house 804
# 804 house done
# at house 805
# 805 house done
# at house 806
# 806 house done
# at house 807
# 807 house done
# at house 808
# 808 house done
# at house 809
# 809 house done
# at house 810
# 810 house done
# at house 811
# 811 house done
# at house 812
# 812 house done
# at house 813
# 813 house done
# at house 814
# 814 house done
# at house 815
# 815 house done
# at house 816
# 816 house done
# at house 817
# 817 house done
# at house 818
# 818 house done
# at house 819
# 819 house done
# at house 820
# 820 house done
# at house 821
# 821 house done
# at house 822
# 822 house done
# at house 823
# 823 house done
# at house 824
# 824 house done
# at house 825
# 825 house done
# at house 826
# 826 house done
# at house 827
# 827 house done
# at house 828
# 828 house done
# at house 829
# 829 house done
# at house 830
# 830 house done
# at house 831
# 831 house done
# at house 832
# 832 house done
# at house 833
# 833 house done
# at house 834
# 834 house done
# at house 835
# 835 house done
# at house 836
# 836 house done
# at house 837
# 837 house done
# at house 838
# 838 house done
# at house 839
# 839 house done
# at house 840
# 840 house done
# at house 841
# 841 house done
# at house 842
# 842 house done
# at house 843
# 843 house done
# at house 844
# 844 house done
# at house 845
# 845 house done
# at house 846
# 846 house done
# at house 847
# 847 house done
# at house 848
# 848 house done
# at house 849
# 849 house done
# at house 850
# 850 house done
# at house 851
# 851 house done
# at house 852
# 852 house done
# at house 853
# 853 house done
# at house 854
# 854 house done
# at house 855
# 855 house done
# at house 856
# 856 house done
# at house 857
# 857 house done
# at house 858
# 858 house done
# at house 859
# 859 house done
# at house 860
# 860 house done
# at house 861
# 861 house done
# at house 862
# 862 house done
# at house 863
# 863 house done
# at house 864
# 864 house done
# at house 865
# 865 house done
# at house 866
# 866 house done
# at house 867
# 867 house done
# at house 868
# 868 house done
# at house 869
# 869 house done
# at house 870
# 870 house done
# at house 871
# 871 house done
# at house 872
# 872 house done
# at house 873
# 873 house done
# at house 874
# 874 house done
# at house 875
# 875 house done
# at house 876
# 876 house done
# at house 877
# 877 house done
# at house 878
# 878 house done
# at house 879
# 879 house done
# at house 880
# 880 house done
# at house 881
# 881 house done
# 1001 house done
# at house 1002
# 1002 house done
# at house 1003
# 1003 house done
# at house 1004
# 1004 house done
# at house 1005
# 1005 house done
# at house 1006
# 1006 house done
# at house 1007
# 1007 house done
# at house 1008
# 1008 house done
# at house 1009
# 1009 house done
# at house 1010
# 1010 house done
# at house 1011
# 1011 house done
# at house 1012
# 1012 house done
# at house 1013
# 1013 house done
# at house 1014
# 1014 house done
# at house 1015
# 1015 house done
# at house 1016
# 1016 house done
# at house 1017
# 1017 house done
# at house 1018
# 1018 house done
# at house 1019
# 1019 house done
# at house 1020
# 1020 house done
# at house 1021
# 1021 house done
# at house 1022
# 1022 house done
# at house 1023
# 1023 house done
# at house 1024
# 1024 house done
# at house 1025
# 1025 house done
# at house 1026
# 1026 house done
# at house 1027
# 1027 house done
# at house 1028
# 1028 house done
# at house 1029
# 1029 house done
# at house 1030
# 1030 house done
# at house 1031
# 1031 house done
# at house 1032
# 1032 house done
# at house 1033
# 1033 house done
# at house 1034
# 1034 house done
# at house 1035
# 1035 house done
# at house 1036
# 1036 house done
# at house 1037
# 1037 house done
# at house 1038
# 1038 house done
# at house 1039
# 1039 house done
# at house 1040
# 1040 house done
# at house 1041
# 1041 house done
# at house 1042
# 1042 house done
# at house 1043
# 1043 house done
# at house 1044
# 1044 house done
# at house 1045
# 1045 house done
# at house 1046
# 1046 house done
# at house 1047
# 1047 house done
# at house 1048
# 1048 house done
# at house 1049
# 1049 house done
# at house 1050
# 1050 house done
# at house 1051
# 1051 house done
# at house 1052
# 1052 house done
# at house 1053
# 1053 house done
# at house 1054
# 1054 house done
# at house 1055
# 1055 house done
# at house 1056
# 1056 house done
# at house 1057
# 1057 house done
# at house 1058
# 1058 house done
# at house 1059
# 1059 house done
# at house 1060
# 1060 house done
# at house 1061
# 1061 house done
# at house 1062
# 1062 house done
# at house 1063
# 1063 house done
# at house 1064
# 1064 house done
# at house 1065
# 1065 house done
# at house 1066
# 1066 house done
# at house 1067
# 1067 house done
# at house 1068
# 1068 house done
# at house 1069
# 1069 house done
# at house 1070
# 1070 house done
# at house 1071
# 1071 house done
# at house 1072
# 1072 house done
# at house 1073
# 1073 house done
# at house 1074
# 1074 house done
# at house 1075
# 1075 house done
# at house 1076
# 1076 house done
# at house 1077
# 1077 house done
# at house 1078
# 1078 house done
# at house 1079
# 1079 house done
# at house 1080
# 1080 house done
# at house 1081
# 1081 house done
# at house 1082
# 1082 house done
# at house 1083
# 1083 house done
# at house 1084
# 1084 house done
# at house 1085
# 1085 house done
# at house 1086
# 1086 house done
# at house 1087
# 1087 house done
# at house 1088
# 1088 house done
# at house 1089
# 1089 house done
# at house 1090
# 1090 house done
# at house 1091
# 1091 house done
# at house 1092
# 1092 house done
# at house 1093
# 1093 house done
# at house 1094
# 1094 house done
# at house 1095
# 1095 house done
# at house 1096
# 1096 house done
# at house 1097
# 1097 house done
# at house 1098
# 1098 house done
# at house 1099
# 1099 house done
# at house 1100
# 1100 house done
# at house 1101
# 1101 house done
# at house 1102
# 1102 house done
# at house 1103
# 1103 house done
# at house 1104
# 1104 house done
# 1208 house done
# at house 1209
# 1209 house done
# at house 1210
# 1210 house done
# at house 1211
# 1211 house done
# at house 1212
# 1212 house done
# at house 1213
# 1213 house done
# at house 1214
# 1214 house done
# at house 1215
# 1215 house done
# at house 1216
# 1216 house done
# at house 1217
# 1217 house done
# at house 1218
# 1218 house done
# at house 1219
# 1219 house done
# at house 1220
# 1220 house done
# at house 1221
# 1221 house done
# at house 1222
# 1222 house done
# at house 1223
# 1223 house done
# at house 1224
# 1224 house done
# at house 1225
# 1225 house done
# at house 1226
# 1226 house done
# at house 1227
# 1227 house done
# at house 1228
# 1228 house done
# at house 1229
# 1229 house done
# at house 1230
# 1230 house done
# at house 1231
# 1231 house done
# at house 1232
# 1232 house done
# at house 1233
# 1233 house done
# at house 1234
# 1234 house done
# at house 1235
# 1235 house done
# at house 1236
# 1236 house done
# at house 1237
# 1237 house done
# at house 1238
# 1238 house done
# at house 1239
# 1239 house done
# at house 1240
# 1240 house done
# at house 1241
# 1241 house done
# at house 1242
# 1242 house done
# at house 1243
# 1243 house done
# at house 1244
# 1244 house done
# at house 1245
# 1245 house done
# at house 1246
# 1246 house done
# at house 1247
# 1247 house done
# at house 1248
# 1248 house done
# at house 1249
# 1249 house done
# at house 1250
# 1250 house done
# at house 1251
# 1251 house done
# at house 1252
# 1252 house done
# at house 1253
# 1253 house done
# at house 1254
# 1254 house done
# at house 1255
# 1255 house done
# at house 1256
# 1256 house done
# at house 1257
# 1257 house done
# at house 1258
# 1258 house done
# at house 1259
# 1259 house done
# at house 1260
# 1260 house done
# at house 1261
# 1261 house done
# at house 1262
# 1262 house done
# at house 1263
# 1263 house done
# at house 1264
# 1264 house done
# at house 1265
# 1265 house done
# at house 1266
# 1266 house done
# at house 1267
# 1267 house done
# at house 1268
# 1268 house done
# at house 1269
# 1269 house done
# at house 1270
# 1270 house done
# at house 1271
# 1271 house done
# at house 1272
# 1272 house done
# at house 1273
# 1273 house done
# at house 1274
# 1274 house done
# at house 1275
# 1275 house done
# at house 1276
# 1276 house done
# at house 1277
# 1277 house done
# at house 1278
# 1278 house done
# at house 1279
# 1279 house done
# at house 1280
# 1280 house done
# at house 1281
# 1281 house done
# at house 1282
# 1282 house done
# at house 1283
# 1283 house done
# at house 1284
# 1284 house done
# at house 1285
# 1285 house done
# at house 1286
# 1286 house done
# at house 1287
# 1287 house done
# at house 1288
# 1288 house done
# at house 1289
# 1289 house done
# at house 1290
# 1290 house done
# at house 1291
# 1291 house done
# at house 1292
# 1292 house done
# at house 1293
# 1293 house done
# at house 1294
# 1294 house done
# at house 1295
# 1295 house done
# at house 1296
# 1296 house done
# at house 1297
# 1297 house done
# at house 1298
# 1298 house done
# at house 1299
# 1299 house done
# at house 1300
# 1300 house done
# at house 1301
# 1301 house done
# at house 1302
# 1302 house done
# at house 1303
# 1303 house done
# at house 1304
# 1304 house done
# at house 1305
# 1305 house done
# at house 1306
# 1306 house done
# at house 1307
# 1307 house done
# at house 1308
# 1308 house done
# at house 1309
# 1309 house done
# at house 1310
# 1310 house done
# at house 1311
# 1311 house done
# at house 1312
# 1623 house done
# at house 1624
# 1624 house done
# at house 1625
# 1625 house done
# at house 1626
# 1626 house done
# at house 1627
# 1627 house done
# at house 1628
# 1628 house done
# at house 1629
# 1629 house done
# at house 1630
# 1630 house done
# at house 1631
# 1631 house done
# at house 1632
# 1632 house done
# at house 1633
# 1633 house done
# at house 1634
# 1634 house done
# at house 1635
# 1635 house done
# at house 1636
# 1636 house done
# at house 1637
# 1637 house done
# at house 1638
# 1638 house done
# at house 1639
# 1639 house done
# at house 1640
# 1640 house done
# at house 1641
# 1641 house done
# at house 1642
# 1642 house done
# at house 1643
# 1643 house done
# at house 1644
# 1644 house done
# at house 1645
# 1645 house done
# at house 1646
# 1646 house done
# at house 1647
# 1647 house done
# at house 1648
# 1648 house done
# at house 1649
# 1649 house done
# at house 1650
# 1650 house done
# at house 1651
# 1651 house done
# at house 1652
# 1652 house done
# at house 1653
# 1653 house done
# at house 1654
# 1654 house done
# at house 1655
# 1655 house done
# at house 1656
# 1656 house done
# at house 1657
# 1657 house done
# at house 1658
# 1658 house done
# at house 1659
# 1659 house done
# at house 1660
# 1660 house done
# at house 1661
# 1661 house done
# at house 1662
# 1662 house done
# at house 1663
# 1663 house done
# at house 1664
# 1664 house done
# at house 1665
# 1665 house done
# at house 1666
# 1666 house done
# at house 1667
# 1667 house done
# at house 1668
# 1668 house done
# at house 1669
# 1669 house done
# at house 1670
# 1670 house done
# at house 1671
# 1671 house done
# at house 1672
# 1672 house done
# at house 1673
# 1673 house done
# at house 1674
# ...
# at house 2468
# 2468 house done
# at house 2469
# 2469 house done
# at house 2470
# 2470 house done
# at house 2471
# 2471 house done
# at house 2472
# 2472 house done
# at house 2473
# 2473 house done
# at house 2474
# 2474 house done
# at house 2475
# 2475 house done
# at house 2476
# 2476 house done
# at house 2477
# 2477 house done
# at house 2478
# 2478 house done
# at house 2479
# 2479 house done
# at house 2480
# 2480 house done
# at house 2481
# 2481 house done
# at house 2482
# 2482 house done
# at house 2483
# 2483 house done
# at house 2484
# 2484 house done
# at house 2485
# 2485 house done
# at house 2486
# 2486 house done
# at house 2487
# 2487 house done
# at house 2488
# 2488 house done
# at house 2489
# 2489 house done
# at house 2490
# 2490 house done
# at house 2491
# 2491 house done
# at house 2492
# 2492 house done
# at house 2493
# 2493 house done
# at house 2494
# 2494 house done
# at house 2495
# 2495 house done
# at house 2496
# 2496 house done
# at house 2497
# 2497 house done
# at house 2498
# 2498 house done
# at house 2499
# 2499 house done
# at house 2500
# 2500 house done
# at house 2501
# 2501 house done
# at house 2502
# 2502 house done
# at house 2503
# 2503 house done
# at house 2504
# 2504 house done
# at house 2505
# 2505 house done
# at house 2506
# 2506 house done
# at house 2507
# 2507 house done
# at house 2508
# 2508 house done
# at house 2509
# 2509 house done
# at house 2510
# 2510 house done
# at house 2511
# 2511 house done
# at house 2512
# 2512 house done
# at house 2513
# 2513 house done
# at house 2514
# 2514 house done
# at house 2515
# 2515 house done
# at house 2516
# 2516 house done
# at house 2517
# 2517 house done
# at house 2518
# 2518 house done
# at house 2519
# 2519 house done
# at house 2520
# 2520 house done
# at house 2521
# 2521 house done
# at house 2522
# 2522 house done
# at house 2523
# 2523 house done
# at house 2524
# 2524 house done
# at house 2525
# 2525 house done
# at house 2526
# 2526 house done
# at house 2527
# 2527 house done
# at house 2528
# 2528 house done
# at house 2529
# 2529 house done
# at house 2530
# 2530 house done
# at house 2531
# 2531 house done
# at house 2532
# 2532 house done
# at house 2533
# 2533 house done
# at house 2534
# 2534 house done
# at house 2535
# 2535 house done
# at house 2536
# 2536 house done
# at house 2537
# 2537 house done
# at house 2538
# 2538 house done
# at house 2539
# 2539 house done
# at house 2540
# 2540 house done
# at house 2541
# 2541 house done
# at house 2542
# 2542 house done
# at house 2543
# 2543 house done
# at house 2544
# 2544 house done
# at house 2545
# 2545 house done
# at house 2546
# 2546 house done
# at house 2547
# 2547 house done
# at house 2548
# 2548 house done
# at house 2549
# 2549 house done
# at house 2550
# 2550 house done
# at house 2551
# 2551 house done
# at house 2552
# 2552 house done
# at house 2553
# 2553 house done
# at house 2554
# 2554 house done
# at house 2555
# 2555 house done
# at house 2556
# 2556 house done
# at house 2557
# 2557 house done
# at house 2558
# 2558 house done
# at house 2559
# 2559 house done
# at house 2560
# 2560 house done
# at house 2561
# 2561 house done
# at house 2562
# 2562 house done
# at house 2563
# 2563 house done
# at house 2564
# 2564 house done
# at house 2565
# 2565 house done
# at house 2566
# 2566 house done
# at house 2567
# 2567 house done
# at house 2568
# 2568 house done
# at house 2569
# 2569 house done
# at house 2570
# 2570 house done
# at house 2571
# 2571 house done
# at house 2572
# 2572 house done
# at house 2573
# 2573 house done
# at house 2574
# 2574 house done
# at house 2575
# 2575 house done
# at house 2576
# 2576 house done
# at house 2577
# 2577 house done
# at house 2578
# 2578 house done
# at house 2579
# 2579 house done
# at house 2580
# 2580 house done
# at house 2581
# 2581 house done
# at house 2582
# 2582 house done
# at house 2583
# 2583 house done
# at house 2584
# 2584 house done
# at house 2585
# 2585 house done
# at house 2586
# 2586 house done
# at house 2587
# 2587 house done
# at house 2588
# 2588 house done
# at house 2589
# 2589 house done
# at house 2590
# 2590 house done
# at house 2591
# 2591 house done
# at house 2592
# 2592 house done
# at house 2593
# 2593 house done
# at house 2594
# 2594 house done
# at house 2595
# 2595 house done
# at house 2596
# 2596 house done
# at house 2597
# 2597 house done
# at house 2598
# 2598 house done
# at house 2599
# 2599 house done
# at house 2600
# 2600 house done
# at house 2601
# 2601 house done
# at house 2602
# 2602 house done
# at house 2603
# 2603 house done
# at house 2604
# 2604 house done
# at house 2605
# 2605 house done
# at house 2606
# 2606 house done
# at house 2607
# 2607 house done
# at house 2608
# 2608 house done
# at house 2609
# 2609 house done
# at house 2610
# 2610 house done
# at house 2611
# 2611 house done
# at house 2612
# 2612 house done
# at house 2613
# 2613 house done
# at house 2614
# 2614 house done
# at house 2615
# 2615 house done
# at house 2616
# 2616 house done
# at house 2617
# 2617 house done
# at house 2618
# 2618 house done
# at house 2619
# 2619 house done
# at house 2620
# 2620 house done
# at house 2621
# 2621 house done
# at house 2622
# 2622 house done
# at house 2623
# 2623 house done
# at house 2624
# at house 2728
# 2728 house done
# at house 2729
# 2729 house done
# at house 2730
# 2730 house done
# at house 2731
# 2731 house done
# at house 2732
# 2732 house done
# at house 2733
# 2733 house done
# at house 2734
# 2734 house done
# at house 2735
# 2735 house done
# at house 2736
# 2736 house done
# at house 2737
# 2737 house done
# at house 2738
# 2738 house done
# at house 2739
# 2739 house done
# at house 2740
# 2740 house done
# at house 2741
# 2741 house done
# at house 2742
# 2742 house done
# at house 2743
# 2743 house done
# at house 2744
# 2744 house done
# at house 2745
# 2745 house done
# at house 2746
# 2746 house done
# at house 2747
# 2747 house done
# at house 2748
# 2748 house done
# at house 2749
# 2749 house done
# at house 2750
# 2750 house done
# at house 2751
# 2751 house done
# at house 2752
# 2752 house done
# at house 2753
# 2753 house done
# at house 2754
# 2754 house done
# at house 2755
# 2755 house done
# at house 2756
# 2756 house done
# at house 2757
# 2757 house done
# at house 2758
# 2758 house done
# at house 2759
# 2759 house done
# at house 2760
# 2760 house done
# at house 2761
# 2761 house done
# at house 2762
# 2762 house done
# at house 2763
# 2763 house done
# at house 2764
# 2764 house done
# at house 2765
# 2765 house done
# at house 2766
# 2766 house done
# at house 2767
# 2767 house done
# at house 2768
# 2768 house done
# at house 2769
# 2769 house done
# at house 2770
# 2770 house done
# at house 2771
# 2771 house done
# at house 2772
# 2772 house done
# at house 2773
# 2773 house done
# at house 2774
# 2774 house done
# at house 2775
# 2775 house done
# at house 2776
# 2776 house done
# at house 2777
# 2777 house done
# at house 2778
# 2778 house done
# at house 2779
# 2779 house done
# at house 2780
# 2780 house done
# at house 2781
# 2781 house done
# at house 2782
# 2782 house done
# at house 2783
# 2783 house done
# at house 2784
# 2784 house done
# at house 2785
# 2785 house done
# at house 2786
# 2786 house done
# at house 2787
# 2787 house done
# at house 2788
# 2788 house done
# at house 2789
# 2789 house done
# at house 2790
# 2790 house done
# at house 2791
# 2791 house done
# at house 2792
# 2792 house done
# at house 2793
# 2793 house done
# at house 2794
# 2794 house done
# at house 2795
# 2795 house done
# at house 2796
# 2796 house done
# at house 2797
# 2797 house done
# at house 2798
# 2798 house done
# at house 2799
# 2799 house done
# at house 2800
# 2800 house done
# at house 2801
# 2801 house done
# at house 2802
# 2802 house done
# at house 2803
# 2803 house done
# at house 2804
# 2804 house done
# at house 2805
# 2805 house done
# at house 2806
# 2806 house done
# at house 2807
# 2807 house done
# at house 2808
# 2808 house done
# at house 2809
# 2809 house done
# at house 2810
# 2810 house done
# at house 2811
# 2811 house done
# at house 2812
# 2812 house done
# at house 2813
# 2813 house done
# at house 2814
# 2814 house done
# at house 2815
# 2815 house done
# at house 2816
# 2816 house done
# at house 2817
# 2817 house done
# at house 2818
# 2818 house done
# at house 2819
# 2819 house done
# at house 2820
# 2820 house done
# at house 2821
# 2821 house done
# at house 2822
# 2822 house done
# at house 2823
# 2823 house done
# at house 2824
# 2824 house done
# at house 2825
# 2825 house done
# at house 2826
# 2826 house done
# at house 2827
# 2827 house done
# at house 2828
# 2828 house done
# at house 2829
# 2829 house done
# at house 2830
# 2830 house done
# at house 2831
# 2831 house done
# at house 2832
# 2832 house done
# at house 2833
# 2833 house done
# at house 2834
# 2834 house done
# at house 2835
# 2835 house done
# at house 2836
# 2836 house done
# at house 2837
# 2837 house done
# at house 2838
# 2838 house done
# at house 2839
# 2839 house done
# at house 2840
# 2840 house done
# at house 2841
# 2841 house done
# at house 2842
# 2842 house done
# at house 2843
# 2843 house done
# at house 2844
# 2844 house done
# at house 2845
# 2845 house done
# at house 2846
# 2846 house done
# at house 2847
# 2847 house done
# at house 2848
# 2848 house done
# at house 2849
# 2849 house done
# at house 2850
# 2850 house done
# at house 2851
# 2851 house done
# at house 2852
# 2852 house done
# at house 2853
# 2853 house done
# at house 2854
# 2854 house done
# at house 2855
# 2855 house done
# at house 2856
# 2856 house done
# at house 2857
# 2857 house done
# at house 2858
# 2858 house done
# at house 2859
# 2859 house done
# at house 2860
# 2860 house done
# at house 2861
# 2861 house done
# at house 2862
# 2862 house done
# at house 2863
# 2863 house done
# at house 2864
# 2864 house done
# at house 2865
# 2865 house done
# at house 2866
# 2866 house done
# at house 2867
# 2867 house done
# at house 2868
# 2868 house done
# at house 2869
# 2869 house done
# at house 2870
# 2870 house done
# at house 2871
# 2871 house done
# at house 2872
# 2872 house done
# at house 2873
# 2873 house done
# at house 2874
# 2874 house done
# at house 2875
# 2875 house done
# at house 2876
# 2876 house done
# at house 2877
# 2877 house done
# at house 2878
# 2878 house done
# at house 2879
# 2879 house done
# at house 2880
# 2880 house done
# at house 2881
# 2881 house done
# at house 2882
# 2882 house done
# at house 2883
# 2883 house done
# at house 2884
# 2884 house done
# at house 2885
# 2885 house done
# at house 2886
# 2886 house done
# at house 2887
# 2887 house done
# at house 2888
# 2888 house done
# at house 2889
# 2889 house done
# at house 2890
# 2890 house done
# at house 2891
# 2891 house done
# at house 2892
# 2892 house done
# at house 2893
# 2893 house done
# at house 2894
# 2894 house done
# at house 2895
# 2895 house done
# at house 2896
# 2896 house done
# at house 2897
# 2897 house done
# at house 2898
# 2898 house done
# at house 2899
# 2899 house done
# at house 2900
# 2900 house done
# at house 2901
# 2901 house done
# at house 2902
# 2902 house done
# at house 2903
# 2903 house done
# at house 2904
# 2904 house done
# at house 2905
# 2905 house done
# at house 2906
# 2906 house done
# at house 2907
# 2907 house done
# at house 2908
# 2908 house done
# at house 2909
# 2909 house done
# at house 2910
# 2910 house done
# at house 2911
# 2911 house done
# at house 2912
# 2912 house done
# at house 2913
# 2913 house done
# at house 2914
# 2914 house done
# at house 2915
# 2915 house done
# at house 2916
# 2916 house done
# at house 2917
# 2917 house done
# at house 2918
# 2918 house done
# at house 2919
# 2919 house done
# at house 2920
# 2920 house done
# at house 2921
# 2921 house done
# at house 2922
# 2922 house done
# at house 2923
# 2923 house done
# at house 2924
# 2924 house done
# at house 2925
# 2925 house done
# at house 2926
# 2926 house done
# at house 2927
# 2927 house done
# at house 2928
# 2928 house done
# at house 2929
# 2929 house done
# at house 2930
# 2930 house done
# at house 2931
# 2931 house done
# at house 2932
# 2932 house done
# at house 2933
# 2933 house done
# at house 2934
# 2934 house done
# at house 2935
# 2935 house done
# at house 2936
# 2936 house done
# at house 2937
# 2937 house done
# at house 2938
# 2938 house done
# at house 2939
# 2939 house done
# at house 2940
# 2940 house done
# at house 2941
# 2941 house done
# at house 2942
# 2942 house done
# at house 2943
# 2943 house done
# at house 2944
# 2944 house done
# at house 2945
# 2945 house done
# at house 2946
# 2946 house done
# at house 2947
# 2947 house done
# at house 2948
# 2948 house done
# at house 2949
# 2949 house done
# at house 2950
# 2950 house done
# at house 2951
# 2951 house done
# at house 2952
# 2952 house done
# at house 2953
# 2953 house done
# at house 2954
# 2954 house done
# at house 2955
# 2955 house done
# at house 2956
# 2956 house done
# at house 2957
# 2957 house done
# at house 2958
# 2958 house done
# at house 2959
# 2959 house done
# at house 2960
# 2960 house done
# at house 2961
# 2961 house done
# at house 2962
# 2962 house done
# at house 2963
# 2963 house done
# at house 2964
# 2964 house done
# at house 2965
# 2965 house done
# at house 2966
# 2966 house done
# at house 2967
# 2967 house done
# at house 2968
# 2968 house done
# at house 2969
# 2969 house done
# at house 2970
# 2970 house done
# at house 2971
# 2971 house done
# at house 2972
# 2972 house done
# at house 2973
# 2973 house done
# at house 2974
# 2974 house done
# at house 2975
# 2975 house done
# at house 2976
# 2976 house done
# at house 2977
# 2977 house done
# at house 2978
# 2978 house done
# at house 2979
# 2979 house done
# at house 2980
# 2980 house done
# at house 2981
# 2981 house done
# at house 2982
# 2982 house done
# at house 2983
# 2983 house done
# at house 2984
# 2984 house done
# at house 2985
# 2985 house done
# at house 2986
# 2986 house done
# at house 2987
# 2987 house done
# at house 2988
# 2988 house done
# at house 2989
# 2989 house done
# at house 2990
# 2990 house done
# at house 2991
# 2991 house done
# at house 2992
# 2992 house done
# at house 2993
# 2993 house done
# at house 2994
# 2994 house done
# at house 2995
# 2995 house done
# at house 2996
# 2996 house done
# at house 2997
# 2997 house done
# at house 2998
# 2998 house done
# at house 2999
# 2999 house done
# at house 3000
# 3000 house done

# %%
sample_feat = np.load('house_feats\\1540\\'+ '1540'+ '.npy')
# sample_feat.tolist()
# sample = []
# sample.append([sample_feat])
# sample
sample_feat
# Out:
# array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#        2.48142385])

# %% [markdown]
# # Concatening all .npy files vertically and saving

# %%
img_data = []
for i in range(1,3001):
    feat = np.load('house_feats\\' + str(i) + '\\'+ str(i) + '.npy')
    img_data.append(feat.tolist())

# %%
print(str(len(img_data)),'x',str(len(img_data[0])))
# Out:
# 3000 x 20480

# %%
np.save('img_data', np.asarray(img_data))

# %% [markdown]
# # Importing data from Excel (Tabular)

# %%
tab_df = pd.read_excel('housing_data.xlsx')

# %%
null_data = tab_df[tab_df.isnull().any(axis=1)]
null_data
# Out:
# Empty DataFrame
# Columns: [NO, Address , Zip, PRICE, bed, bath, size, build year, lot area, HOA, Elementary, Middle, Highschool, Season (Winter or not)]
# Index: []

# %%
tab_df
# Out:
#         NO                                     Address     Zip   PRICE  bed  \
# 0        1       5316 Hidden Creek Cir, Mason, OH 45040  45040  420000    4
# 1        2       6309 Tarton Fields Ln, Mason, OH 45040  45040  630000    4
# 2        3            756 Tradewind Dr, Mason, OH 45040  45040  259755    3
# 3        4             9639 Fox Run Dr, Mason, OH 45040  45040  396000    4
# 4        5                5837 Lisa Ct, Mason, OH 45040  45040  385000    4
# ...    ...                                          ...    ...     ...  ...
# 2995  2996        306 Loggerhead Dr, Columbia, SC 29229  29229  230000    3
# 2996  2997            145 Aster Cir, Columbia, SC 29201  29201  115000    3
# 2997  2998      204 Terrapin Trce E, Columbia, SC 29229  29229  285000    3
# 2998  2999          1014 Laurens St, Columbia, SC 29201  29201  388000    3
# 2999  3000  126 Heritage Village Ln, Columbia, SC 29212  29212  156000    2
#
#       bath    size  build year  lot area    HOA  Elementary  Middle  \
# 0      4.0  2019.0        1992      0.38  185.0           5       6
# 1      5.0  4526.0        1997      0.51  495.0           5       6
# 2      2.0  1431.0        1974      0.40    0.0           5       6
# 3      3.0  2523.0        1989      0.36    0.0           5       6
# 4      4.0  3322.0        1993      0.43  115.0           5       6
# ...    ...     ...         ...       ...    ...         ...     ...
# 2995   2.0  1800.0        1998      0.23   12.0           6       6
# 2996   1.5  1000.0        1971      0.13    0.0           4       5
# 2997   2.0  1864.0        2000     65.70   12.0           6       6
# 2998   3.0  2622.0        1910      0.12    0.0           5       5
# 2999   2.0  1092.0        1998      0.12   21.0           3       4
#
#       Highschool  Season (Winter or not)
# 0              3                       1
# 1              3                       1
# 2              3                       1
# 3              3                       1
# 4              3                       1
# ...          ...                     ...
# 2995           6                       1
# 2996           7                       1
# 2997           6                       1
# 2998           7                       1
# 2999           2                       1
#
# [3000 rows x 14 columns]

# %%
tab_df.nunique()
# Out:
# NO                        3000
# Address                   2982
# Zip                        439
# PRICE                     1122
# bed                         10
# bath                        18
# size                      1635
# build year                 156
# lot area                   346
# HOA                        237
# Elementary                  11
# Middle                      10
# Highschool                  11
# Season (Winter or not)       3
# dtype: int64

# %% [markdown]
# ## Applying transformations on the tabular dataset

# %%
#Dropping 'no' and 'address'
tab_df = tab_df.drop(['NO', 'Address '], axis = 1)

# %%
tab_df
# Out:
#         Zip   PRICE  bed  bath    size  build year  lot area    HOA  \
# 0     45040  420000    4   4.0  2019.0        1992      0.38  185.0
# 1     45040  630000    4   5.0  4526.0        1997      0.51  495.0
# 2     45040  259755    3   2.0  1431.0        1974      0.40    0.0
# 3     45040  396000    4   3.0  2523.0        1989      0.36    0.0
# 4     45040  385000    4   4.0  3322.0        1993      0.43  115.0
# ...     ...     ...  ...   ...     ...         ...       ...    ...
# 2995  29229  230000    3   2.0  1800.0        1998      0.23   12.0
# 2996  29201  115000    3   1.5  1000.0        1971      0.13    0.0
# 2997  29229  285000    3   2.0  1864.0        2000     65.70   12.0
# 2998  29201  388000    3   3.0  2622.0        1910      0.12    0.0
# 2999  29212  156000    2   2.0  1092.0        1998      0.12   21.0
#
#       Elementary  Middle  Highschool  Season (Winter or not)
# 0              5       6           3                       1
# 1              5       6           3                       1
# 2              5       6           3                       1
# 3              5       6           3                       1
# 4              5       6           3                       1
# ...          ...     ...         ...                     ...
# 2995           6       6           6                       1
# 2996           4       5           7                       1
# 2997           6       6           6                       1
# 2998           5       5           7                       1
# 2999           3       4           2                       1
#
# [3000 rows x 12 columns]

# %%
minmax_df = tab_df[tab_df.columns[[0,2,3,4,5,6,7,8,9,10]]]

mmscaler = MinMaxScaler()
mmscaler2 = MinMaxScaler()

minmax_df = mmscaler.fit_transform(minmax_df)

tab_df[tab_df.columns[[0,2,3,4,5,6,7,8,9,10]]] = minmax_df

tab_df
# Out:
#            Zip   PRICE       bed      bath      size  build year  lot area  \
# 0     0.439636  420000  0.100000  0.003293  0.144035    0.054281  0.000025
# 1     0.439636  630000  0.100000  0.004391  0.323114    0.054544  0.000033
# 2     0.439636  259755  0.066667  0.001098  0.102034    0.053331  0.000026
# 3     0.439636  396000  0.100000  0.002195  0.180037    0.054122  0.000024
# 4     0.439636  385000  0.100000  0.003293  0.237111    0.054333  0.000028
# ...        ...     ...       ...       ...       ...         ...       ...
# 2995  0.274910  230000  0.066667  0.001098  0.128392    0.054597  0.000015
# 2996  0.274619  115000  0.066667  0.000549  0.071247    0.053173  0.000009
# 2997  0.274910  285000  0.066667  0.001098  0.132963    0.054703  0.004315
# 2998  0.274619  388000  0.066667  0.002195  0.187109    0.049955  0.000008
# 2999  0.274733  156000  0.033333  0.001098  0.077818    0.054597  0.000008
#
#            HOA  Elementary    Middle  Highschool  Season (Winter or not)
# 0     0.062712         0.5  0.555556         0.3                       1
# 1     0.167797         0.5  0.555556         0.3                       1
# 2     0.000000         0.5  0.555556         0.3                       1
# 3     0.000000         0.5  0.555556         0.3                       1
# 4     0.038983         0.5  0.555556         0.3                       1
# ...        ...         ...       ...         ...                     ...
# 2995  0.004068         0.6  0.555556         0.6                       1
# 2996  0.000000         0.4  0.444444         0.7                       1
# 2997  0.004068         0.6  0.555556         0.6                       1
# 2998  0.000000         0.5  0.444444         0.7                       1
# 2999  0.007119         0.3  0.333333         0.2                       1
#
# [3000 rows x 12 columns]

# %%
#target
y = tab_df['PRICE']/10000

#saving target
np.save('target.npy', np.asarray(y))

#calculating normalized price 3 ways
nrm_price = (y.max() + y.min()) / 2
nrm_price_avg = y.mean()
nrm_price_med = y.median()

# %%
tab_df = tab_df.drop('PRICE', 1)
tab_df
# Out:
# C:\Users\Vaddi\AppData\Local\Temp/ipykernel_18936/2671169235.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   tab_df = tab_df.drop('PRICE', 1)
#            Zip       bed      bath      size  build year  lot area       HOA  \
# 0     0.439636  0.100000  0.003293  0.144035    0.054281  0.000025  0.062712
# 1     0.439636  0.100000  0.004391  0.323114    0.054544  0.000033  0.167797
# 2     0.439636  0.066667  0.001098  0.102034    0.053331  0.000026  0.000000
# 3     0.439636  0.100000  0.002195  0.180037    0.054122  0.000024  0.000000
# 4     0.439636  0.100000  0.003293  0.237111    0.054333  0.000028  0.038983
# ...        ...       ...       ...       ...         ...       ...       ...
# 2995  0.274910  0.066667  0.001098  0.128392    0.054597  0.000015  0.004068
# 2996  0.274619  0.066667  0.000549  0.071247    0.053173  0.000009  0.000000
# 2997  0.274910  0.066667  0.001098  0.132963    0.054703  0.004315  0.004068
# 2998  0.274619  0.066667  0.002195  0.187109    0.049955  0.000008  0.000000
# 2999  0.274733  0.033333  0.001098  0.077818    0.054597  0.000008  0.007119
#
#       Elementary    Middle  Highschool  Season (Winter or not)
# 0            0.5  0.555556         0.3                       1
# 1            0.5  0.555556         0.3                       1
# 2            0.5  0.555556         0.3                       1
# 3            0.5  0.555556         0.3                       1
# 4            0.5  0.555556         0.3                       1
# ...          ...       ...         ...                     ...
# 2995         0.6  0.555556         0.6                       1
# 2996         0.4  0.444444         0.7                       1
# 2997         0.6  0.555556         0.6                       1
# 2998         0.5  0.444444         0.7                       1
# 2999         0.3  0.333333         0.2                       1
#
# [3000 rows x 11 columns]

# %%
img_data = np.load(r'img_data.npy')

#minmax scaling images
# img_data_scaled  = mmscaler2.fit_transform(img_data)

# img_data_scaled = img_data_scaled.tolist()

# print(int(len(img_data_scaled[0])/5))

# l = [1,2,3,4,5,6]
# r = []
# for i in range(0, 7, 2):
#     r.append(sum(l[i:i+2]))
# r

# %% [markdown]
# # Computing l2 norm of each image (4096) for every house (20480 total for 5 images)

# %%
def l2_convert(row):
    l2_imgs = []
    jump = int(len(row)/5)
    for i in range(0, len(row), jump):
        img = row[i:i+jump]
        img_norm = np.linalg.norm(img)
        img_normalized = img/img_norm
        l2_imgs.extend(img_normalized)
    return l2_imgs

#computing and appending l2 norm of each image for each house(2000)
img_data_l2 = list(map(l2_convert, img_data))

# print(str(len(img_data_l2)), 'x', str(len(img_data_l2[0])))
img_data_l2 = np.asarray(img_data_l2)
img_data_l2.shape
# Out:
# (3000, 20480)

# %%
tab_data = np.asarray(tab_df)

def tab_l2_convert(row):
    row_norm = np.linalg.norm(row)
    return row/row_norm 

tab_data_l2 = list(map(tab_l2_convert, tab_data))
tab_data_l2 = np.asarray(tab_data_l2)

# %%
print(img_data_l2.shape)
print(tab_data_l2.shape)
# Out:
# (3000, 20480)
# (3000, 11)

# %% [markdown]
# # Concatenating tabular feat-dims (11) with image feat-dims (20480) for each house

# %%
final_data = np.concatenate((tab_data_l2, img_data_l2), axis = 1)

# shape of final dataset
print(final_data.shape)
# Out:
# (3000, 20491)

# %%
type(final_data)
# Out:
# numpy.ndarray

# %%
#saving final dataset
np.save('final_data',final_data)

# %% [markdown]
# # Loading saved final data

# %%
final_data = np.load(r'final_data.npy')

# %%
#Train test split
final_data_train, final_data_test, y_train, y_test = train_test_split(final_data, y, test_size = 0.1, random_state = 1)

# %%
final_data_train.shape
# Out:
# (2700, 20491)

# %% [markdown]
# # Constructing linear multi-kernel for SVR and normalizing ground truth values

# %%
# building training kernel
mlk_train = np.dot(final_data_train, final_data_train.transpose())

# %%
# building testing kernel
mlk_test = np.dot(final_data_test, final_data_train.transpose())

# %%
#converting to ndarrays

y_train = np.asarray(y_train)
y_test = np.asarray(y_test)
y_train
# Out:
# array([ 9.19  , 21.3579, 11.2   , ..., 28.5   , 49.99  , 43.5   ])

# %%
pd.DataFrame(mlk_train).to_csv('mlk_train.csv',index = False, header = False)
pd.DataFrame(mlk_test).to_csv('mlk_test.csv',index = False, header = False)

# %%
# Normalizing y_train
y_train_nrm = np.asarray(y_train - nrm_price)
y_train_nrm_avg = np.asarray(y_train - nrm_price_avg)
y_train_nrm_med = np.asarray(y_train - nrm_price_med)

# %%
#reshaping for compatibility
y_train = y_train.reshape(2700)
y_train_nrm = y_train_nrm.reshape(2700)
y_train_nrm_avg = y_train_nrm_avg.reshape(2700)
y_train_nrm_med = y_train_nrm_med.reshape(2700)

y_test = y_test.reshape(300)

# %%
# viewing shape

mlk_train.shape
# Out:
# (2700, 2700)

# %%
# viewing shape

mlk_test.shape
# Out:
# (300, 2700)

# %%
#viewing shape

y_train_nrm.shape
# Out:
# (2700,)

# %%
#viewing shape

y_test.shape
# Out:
# (300,)

# %%
y_train_nrm
# Out:
# array([-224.9764, -212.8085, -222.9664, ..., -205.6664, -184.1764,
#        -190.6664])

# %%
#saving as exel file for review
pd.DataFrame(mlk_train).to_csv('mlk_train.csv', index = False, header = False)
pd.DataFrame(mlk_test).to_csv('mlk_test.csv',index = False, header = False)

# %% [markdown]
# # Creating SVR model and predicting

# %%
#initiating SVR Objects for each normalized target
svr = SVR(kernel= 'precomputed')
svr_nrm = SVR(kernel= 'precomputed')
svr_nrm_avg = SVR(kernel= 'precomputed')
svr_nrm_med = SVR(kernel= 'precomputed')

#fitting the SVR models
svr.fit(mlk_train, y_train) 
svr_nrm.fit(mlk_train, y_train_nrm) 
svr_nrm_avg.fit(mlk_train, y_train_nrm_avg)
svr_nrm_med.fit(mlk_train, y_train_nrm_med)

#predictions
y_pred = svr.predict(mlk_test)
y_pred_nrm = svr_nrm.predict(mlk_test)
y_pred_nrm_avg = svr_nrm_avg.predict(mlk_test)
y_pred_nrm_med = svr_nrm_med.predict(mlk_test)

# %% [markdown]
# # Evaluating Predictions using Mean Absolute Error with and without normalized result

# %%
#printing error
error0 = mean_absolute_error(y_test, np.absolute(y_pred))
print('Error w/o normalization:', error0)

error1 = mean_absolute_error(y_test, np.absolute(y_pred_nrm + nrm_price))
print('Error ( (min+max)/2 ):  ', error1)

error2 = mean_absolute_error(y_test, np.absolute(y_pred_nrm_avg + nrm_price_avg))
print('Error (nrm_avg):\t', error2)

error3 = mean_absolute_error(y_test, np.absolute(y_pred_nrm_med + nrm_price_med))
print('Error (nrm_med):\t', error3)
# Out:
# Error w/o normalization: 17.00212260497358
# Error ( (min+max)/2 ):   17.0021226049736
# Error (nrm_avg):	 17.00212260497358
# Error (nrm_med):	 17.002122604973575

# %%
y_test_df = pd.DataFrame(y_test)
y_pred_df = pd.DataFrame(y_pred)
y_pred_nrm_df = pd.DataFrame(y_pred_nrm + nrm_price)
y_pred_avg_df = pd.DataFrame(y_pred_nrm_avg + nrm_price_avg)
y_pred_mid_df = pd.DataFrame(y_pred_nrm_med + nrm_price_med)

# %%
y_test_df.to_csv('y_test.csv', index = False, header = False)
y_pred_df.to_csv('y_pred.csv', index = False, header = False)
y_pred_nrm_df.to_csv('y_pred_nrm.csv', index = False, header = False)
y_pred_avg_df.to_csv('y_pred_nrm_avg.csv', index = False, header = False)
y_pred_mid_df.to_csv('y_pred_nrm_med.csv', index = False, header = False)
